# %% [markdown]
# # <span style="color:darkblue"> Lecture 23c Advanced Merging </span>
#
# <font size = "5">
#
# In this lecture we will see how to merge datasets <br>
# with multiple primary keys

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %% [markdown]
# <font size = "5">
#
# Import libraries

# %%
# psycogpg2 helps us process SQL commands to send to the server
# sqlalchemy facilitates establishing a connection with the server

import pandas as pd
from sqlalchemy import create_engine
from   sqlalchemy.engine import URL
from   sqlalchemy import text

# %% [markdown]
# <font size = "5">
#
# Connect to SQL server
#
# - In the default instructions we set <br>
# the password to "12345" in windows and <br>
# no password for Mac
# - ADJUST code accordingly!

# %%
# Use the connection details to your server
# These are the default settings.
# "postgresql" is a fixed argument
# If you have a different host,database, username, or password,
# change the corresponding connection details


url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'postgres',
    username = 'postgres',
    port = 5432,
    password  = "8848")

connection = create_engine(url_server)

# %% [markdown]
# <font size = "5">
#
# Read datasets into Python

# %%
bills_actions   = pd.read_csv("data_raw/bills_actions.csv")
bills_subjects  = pd.read_csv("data_raw/bills_actions.csv")

# %% [markdown]
# <font size = "5">
#
# Upload to SQL

# %%
bills_actions.to_sql('bills_actions',
               con = connection,
               if_exists='replace',
               index=False)

bills_subjects.to_sql('bills_subjects',
               con = connection,
               if_exists='replace',
               index=False)
# Out:
# 303

# %% [markdown]
# <font size = "5">
#
# Merge two datasets where the primary key is given by multiple variables

# %%
# Write your own code


example = pd.read_sql(text("SELECT * \
                            FROM bills_actions \
                            LEFT JOIN bills_subjects \
                            ON bills_actions.congress = bills_subjects.congress \
                                AND bills_actions.bill_number = bills_subjects.bill_number \
                                AND bills_actions.bill_type = bills_subjects.bill_type;"),
                      connection)

example
# Out:
#         congress  bill_number bill_type  \
# 0            116            1     hjres
# 1            116            1        hr
# 2            116            1        hr
# 3            116            1        hr
# 4            116            1        hr
# ...          ...          ...       ...
# 128668       116         8611        hr
# 128669       116         8810        hr
# 128670       116         8900        hr
# 128671       116         8906        hr
# 128672       116         9051        hr
#
#                                                    action  \
# 0       Ms. Granger moved to recommit to the Committee...
# 1       POSTPONED PROCEEDINGS - At the conclusion of d...
# 2       POSTPONED PROCEEDINGS - At the conclusion of d...
# 3       POSTPONED PROCEEDINGS - At the conclusion of d...
# 4       POSTPONED PROCEEDINGS - At the conclusion of d...
# ...                                                   ...
# 128668  Ms. Kelly (IL) asked unanimous consent to disc...
# 128669  Mr. Case moved to suspend the rules and pass t...
# 128670  Ms. DeLauro moved to suspend the rules and pas...
# 128671  Mrs. Dingell asked unanimous consent to discha...
# 128672  Mr. Neal moved to suspend the rules and pass t...
#
#                                  main_action                  object  \
# 0       house committee/subcommittee actions  house joint resolution
# 1              other house amendment actions               amendment
# 2              other house amendment actions               amendment
# 3              other house amendment actions               amendment
# 4              other house amendment actions               amendment
# ...                                      ...                     ...
# 128668                   house floor actions              house bill
# 128669                   house floor actions              house bill
# 128670                   house floor actions              house bill
# 128671                   house floor actions              house bill
# 128672                   house floor actions              house bill
#
#         member_id  congress  bill_number bill_type  \
# 0             693       116            1     hjres
# 1            1152       116            1        hr
# 2            1152       116            1        hr
# 3            1152       116            1        hr
# 4            1152       116            1        hr
# ...           ...       ...          ...       ...
# 128668       1695       116         8611        hr
# 128669        332       116         8810        hr
# 128670       1018       116         8900        hr
# 128671       1371       116         8906        hr
# 128672       1671       116         9051        hr
#
#                                                    action  \
# 0       Ms. Granger moved to recommit to the Committee...
# 1       POSTPONED PROCEEDINGS - At the conclusion of d...
# 2       H.Amdt.58 Amendment (A005) offered by Mr. Cole...
# 3       H.Amdt.57 Amendment (A004) offered by Mr. Hast...
# 4       H.Amdt.56 Amendment (A003) offered by Mr. Rask...
# ...                                                   ...
# 128668  Ms. Kelly (IL) asked unanimous consent to disc...
# 128669  Mr. Case moved to suspend the rules and pass t...
# 128670  Ms. DeLauro moved to suspend the rules and pas...
# 128671  Mrs. Dingell asked unanimous consent to discha...
# 128672  Mr. Neal moved to suspend the rules and pass t...
#
#                                  main_action                  object  \
# 0       house committee/subcommittee actions  house joint resolution
# 1              other house amendment actions               amendment
# 2                    house amendment offered               amendment
# 3                    house amendment offered               amendment
# 4                    house amendment offered               amendment
# ...                                      ...                     ...
# 128668                   house floor actions              house bill
# 128669                   house floor actions              house bill
# 128670                   house floor actions              house bill
# 128671                   house floor actions              house bill
# 128672                   house floor actions              house bill
#
#         member_id
# 0             693
# 1            1152
# 2            1152
# 3            1238
# 4             521
# ...           ...
# 128668       1695
# 128669        332
# 128670       1018
# 128671       1371
# 128672       1671
#
# [128673 rows x 14 columns]
